# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/nitheshsrb/Documents/VSCode/Git/Fundamentals'

# %%
df = pd.read_csv('analytics_project_1/data/sales_data.csv')

# %%
df.head(
)
# Out:
# 0 customer_id clinic purchase_date amount
# 1           1      A    2024-01-01     50
# 2           1      A    2024-02-10     30
# 3           2      B    2024-01-20    100
# 4           3      A    2024-02-15     20
# 5           2      B    2024-02-20     40

# %%
df.columns = df.iloc[0]
df = df[['customer_id','clinic','purchase_date','amount']]
df = df.iloc[1:]
